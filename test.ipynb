# %%
import FinanceDataReader as fdr
import pandas as pd

# 한국 주식 리스트 가져오기
stocks = fdr.StockListing('NASDAQ')
# Out:
# 100%|██████████| 3705/3705 [00:03<00:00, 1112.97it/s]

# %%
stocks.sample(10)
# Out:
#      Symbol                                   Name IndustryCode  \
# 2080   OCCI                 OFS Credit Company Inc     55501030
# 2881    HWH                  HWH International Inc     57201020
# 1064   EMBC                           Embecta Corp     56101020
# 1389   CYRX                           Cryoport Inc     52405010
# 1226   MRVI      Maravai LifeSciences Holdings Inc     56202010
# 679    UPWK                             Upwork Inc     52203030
# 1421   PERI                     Perion Network Ltd     57201020
# 1210   MOFG  Midwestone Financial Group Inc (IOWA)     55101010
# 1628   LOCO             El Pollo Loco Holdings Inc     53301020
# 1106   NBBK                         NB Bancorp Inc     55101010
#
#                    Industry
# 2080                 폐쇄형 펀드
# 2881                  소프트웨어
# 1064         의료 장비, 물품 및 유통
# 1389  배달, 우편, 항공 화물 및 육상 물류
# 1226          생명 공학 및 의학 연구
# 679                  고용 서비스
# 1421                  소프트웨어
# ...
